# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import netCDF4
#import cmocean

from mpl_toolkits.basemap import Basemap

# %matplotlib inline

# %%
sns.set_style('white')
sns.set_context('paper', font_scale=2)
sns.set_palette('hls', 6)
sns.set_style('ticks')

# %%
# max and min for range showing mld 
vmax = 1500.0
vmin = 0.0

# %%
# southern polar projection 
#map = Basemap(projection='spstere',boundinglat=-50, lon_0=180+(-100+-30)/2.,resolution='c')
map = Basemap(projection='spstere',boundinglat=-50, lon_0=180.,resolution='c')

# %%
# obs from Hosada 

fname = "/archive/gold/datasets/obs/Hosada2010_MLD_climatology.v20140515.nc"
MLD_obs = netCDF4.Dataset(fname).variables['MLD']

#= netCDF4.Dataset(cmdLineArgs.obsdata).variables['MLD'][:]

x_obs = netCDF4.Dataset(fname).variables['LONGITUDE'][:]
y_obs = netCDF4.Dataset(fname).variables['LATITUDE'][:]

mld03_obs = MLD_obs[2,:,:]
mld09_obs = MLD_obs[8,:,:]

#print(MLD_obs.shape,x_obs.shape,y_obs.shape,mld03_obs.shape)

# %%
# 1988-2007 mean March and September MLD for OM4p25 

dirname = "/archive/ogrp/CMIP6/OMIP/warsaw_201803_mom6_2018.04.06"

fname_a = dirname+"/OM4p25_IAF_BLING_CFC_csf/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1988-1992.03.nc"
fname_b = dirname+"/OM4p25_IAF_BLING_CFC_csf/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1993-1997.03.nc"
fname_c = dirname+"/OM4p25_IAF_BLING_CFC_csf/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1998-2002.03.nc"
fname_d = dirname+"/OM4p25_IAF_BLING_CFC_csf/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.2003-2007.03.nc"

#for v in netCDF4.Dataset(fname_a).variables: print("variables =",v)

mld_a = netCDF4.Dataset(fname_a).variables['mlotst']
mld_b = netCDF4.Dataset(fname_b).variables['mlotst']
mld_c = netCDF4.Dataset(fname_c).variables['mlotst']
mld_d = netCDF4.Dataset(fname_d).variables['mlotst']

mld_a = np.squeeze(mld_a,axis=0)
mld_b = np.squeeze(mld_b,axis=0)
mld_c = np.squeeze(mld_c,axis=0)
mld_d = np.squeeze(mld_d,axis=0)

mld03_p25 = 0.25*(mld_a+mld_b+mld_c+mld_d)


fname_a = dirname+"/OM4p25_IAF_BLING_CFC_csf/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1988-1992.09.nc"
fname_b = dirname+"/OM4p25_IAF_BLING_CFC_csf/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1993-1997.09.nc"
fname_c = dirname+"/OM4p25_IAF_BLING_CFC_csf/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1998-2002.09.nc"
fname_d = dirname+"/OM4p25_IAF_BLING_CFC_csf/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.2003-2007.09.nc"

mld_a = netCDF4.Dataset(fname_a).variables['mlotst']
mld_b = netCDF4.Dataset(fname_b).variables['mlotst']
mld_c = netCDF4.Dataset(fname_c).variables['mlotst']
mld_d = netCDF4.Dataset(fname_d).variables['mlotst']

mld_a = np.squeeze(mld_a,axis=0)
mld_b = np.squeeze(mld_b,axis=0)
mld_c = np.squeeze(mld_c,axis=0)
mld_d = np.squeeze(mld_d,axis=0)

mld09_p25 = 0.25*(mld_a+mld_b+mld_c+mld_d)


yh_p25 = netCDF4.Dataset(fname_a).variables['yh']
xh_p25 = netCDF4.Dataset(fname_a).variables['xh']

# %%
# 1988-2007 mean March and September MLD for OM4p5 

dirname = "/archive/oar.gfdl.bgrp-account/CMIP6/OMIP/warsaw_201803_mom6_2018.04.11"

fname_a = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle200/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1988-1992.03.nc"
fname_b = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle200/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1993-1997.03.nc"
fname_c = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle200/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1998-2002.03.nc"
fname_d = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle200/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.2003-2007.03.nc"

#for v in netCDF4.Dataset(fname_a).variables: print("variables =",v)

mld_a = netCDF4.Dataset(fname_a).variables['mlotst']
mld_b = netCDF4.Dataset(fname_b).variables['mlotst']
mld_c = netCDF4.Dataset(fname_c).variables['mlotst']
mld_d = netCDF4.Dataset(fname_d).variables['mlotst']

mld_a = np.squeeze(mld_a,axis=0)
mld_b = np.squeeze(mld_b,axis=0)
mld_c = np.squeeze(mld_c,axis=0)
mld_d = np.squeeze(mld_d,axis=0)

mld03_p5 = 0.25*(mld_a+mld_b+mld_c+mld_d)


fname_a = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle200/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1988-1992.09.nc"
fname_b = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle200/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1993-1997.09.nc"
fname_c = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle200/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1998-2002.09.nc"
fname_d = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle200/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.2003-2007.09.nc"

mld_a = netCDF4.Dataset(fname_a).variables['mlotst']
mld_b = netCDF4.Dataset(fname_b).variables['mlotst']
mld_c = netCDF4.Dataset(fname_c).variables['mlotst']
mld_d = netCDF4.Dataset(fname_d).variables['mlotst']

mld_a = np.squeeze(mld_a,axis=0)
mld_b = np.squeeze(mld_b,axis=0)
mld_c = np.squeeze(mld_c,axis=0)
mld_d = np.squeeze(mld_d,axis=0)

mld09_p5 = 0.25*(mld_a+mld_b+mld_c+mld_d)

yh_p5 = netCDF4.Dataset(fname_a).variables['yh']
xh_p5 = netCDF4.Dataset(fname_a).variables['xh']

# %%
# 1988-2007 mean March and September MLD for OM4p5nn 

dirname = "/archive/oar.gfdl.bgrp-account/CMIP6/OMIP/warsaw_201803_mom6_2018.04.11"

fname_a = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle500/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1988-1992.03.nc"
fname_b = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle500/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1993-1997.03.nc"
fname_c = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle500/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1998-2002.03.nc"
fname_d = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle500/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.2003-2007.03.nc"

#for v in netCDF4.Dataset(fname_a).variables: print("variables =",v)

mld_a = netCDF4.Dataset(fname_a).variables['mlotst']
mld_b = netCDF4.Dataset(fname_b).variables['mlotst']
mld_c = netCDF4.Dataset(fname_c).variables['mlotst']
mld_d = netCDF4.Dataset(fname_d).variables['mlotst']

mld_a = np.squeeze(mld_a,axis=0)
mld_b = np.squeeze(mld_b,axis=0)
mld_c = np.squeeze(mld_c,axis=0)
mld_d = np.squeeze(mld_d,axis=0)

mld03_p5nn = 0.25*(mld_a+mld_b+mld_c+mld_d)


fname_a = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle500/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1988-1992.09.nc"
fname_b = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle500/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1993-1997.09.nc"
fname_c = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle500/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1998-2002.09.nc"
fname_d = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_mle500/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.2003-2007.09.nc"

mld_a = netCDF4.Dataset(fname_a).variables['mlotst']
mld_b = netCDF4.Dataset(fname_b).variables['mlotst']
mld_c = netCDF4.Dataset(fname_c).variables['mlotst']
mld_d = netCDF4.Dataset(fname_d).variables['mlotst']

mld_a = np.squeeze(mld_a,axis=0)
mld_b = np.squeeze(mld_b,axis=0)
mld_c = np.squeeze(mld_c,axis=0)
mld_d = np.squeeze(mld_d,axis=0)

mld09_p5nn = 0.25*(mld_a+mld_b+mld_c+mld_d)

#yh_p5 = netCDF4.Dataset(fname_a).variables['yh']
#xh_p5 = netCDF4.Dataset(fname_a).variables['xh']

# %%
# 1988-2007 mean March and September MLD for OM4p5n 

dirname = "/archive/oar.gfdl.bgrp-account/CMIP6/OMIP/warsaw_201803_mom6_2018.04.11"

fname_a = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_p25config/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1988-1992.03.nc"
fname_b = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_p25config/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1993-1997.03.nc"
fname_c = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_p25config/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1998-2002.03.nc"
fname_d = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_p25config/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.2003-2007.03.nc"

#for v in netCDF4.Dataset(fname_a).variables: print("variables =",v)

mld_a = netCDF4.Dataset(fname_a).variables['mlotst']
mld_b = netCDF4.Dataset(fname_b).variables['mlotst']
mld_c = netCDF4.Dataset(fname_c).variables['mlotst']
mld_d = netCDF4.Dataset(fname_d).variables['mlotst']

mld_a = np.squeeze(mld_a,axis=0)
mld_b = np.squeeze(mld_b,axis=0)
mld_c = np.squeeze(mld_c,axis=0)
mld_d = np.squeeze(mld_d,axis=0)

mld03_p5n = 0.25*(mld_a+mld_b+mld_c+mld_d)


fname_a = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_p25config/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1988-1992.09.nc"
fname_b = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_p25config/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1993-1997.09.nc"
fname_c = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_p25config/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.1998-2002.09.nc"
fname_d = dirname+"/OM4p5_IAF_BLING_CFC_abio_csf_p25config/gfdl.ncrc4-intel16-prod/pp/ocean_monthly/av/monthly_5yr/ocean_monthly.2003-2007.09.nc"

mld_a = netCDF4.Dataset(fname_a).variables['mlotst']
mld_b = netCDF4.Dataset(fname_b).variables['mlotst']
mld_c = netCDF4.Dataset(fname_c).variables['mlotst']
mld_d = netCDF4.Dataset(fname_d).variables['mlotst']

mld_a = np.squeeze(mld_a,axis=0)
mld_b = np.squeeze(mld_b,axis=0)
mld_c = np.squeeze(mld_c,axis=0)
mld_d = np.squeeze(mld_d,axis=0)

mld09_p5n = 0.25*(mld_a+mld_b+mld_c+mld_d)

#yh_p5 = netCDF4.Dataset(fname_a).variables['yh']
#xh_p5 = netCDF4.Dataset(fname_a).variables['xh']

# %%
fig, axis = plt.subplots(1,1, figsize=(12,12))

field = np.ma.masked_greater(mld09_p25,1e6)
X = xh_p25[:]
Y = yh_p25[:]

Lon,Lat = np.meshgrid(X,Y)
x,y = map(Lon,Lat)

cs = map.pcolormesh(x, y, field, shading='flat', cmap='viridis', vmin=vmin, vmax=vmax)
cbar = map.colorbar(cs)
cbar.outline.set_linewidth(1)

plt.title("September MLD for 1988-2007 in OM4p25",fontsize=20)

map.drawparallels(np.arange(-80.,81.,20.))
map.drawmeridians(np.arange(-180.,181.,20.))

fig.savefig('./figures/SO_mld09_OM4p25.png', bbox_inches='tight', dpi=300)

plt.show()

# %%
fig, axis = plt.subplots(1,1, figsize=(12,12))


field = np.ma.masked_greater(mld09_p5,1e6)
X = xh_p5[:]
Y = yh_p5[:]

Lon,Lat = np.meshgrid(X,Y)
x,y = map(Lon,Lat)

cs = map.pcolormesh(x, y, field, shading='flat', cmap='viridis', vmin=vmin, vmax=vmax)
cbar = map.colorbar(cs)
cbar.outline.set_linewidth(1)
map.drawparallels(np.arange(-80.,81.,20.))
map.drawmeridians(np.arange(-180.,181.,20.))

plt.title("September MLD for 1988-2007 in OM4p5",fontsize=20)
fig.savefig('./figures/SO_mld09_OM4p5.png', bbox_inches='tight', dpi=300)

plt.show()

# %%
fig, axis = plt.subplots(1,1, figsize=(12,12))

field = np.ma.masked_greater(mld09_p5nn,1e6)
X = xh_p5[:]
Y = yh_p5[:]

Lon,Lat = np.meshgrid(X,Y)
x,y = map(Lon,Lat)

cs = map.pcolormesh(x, y, field, shading='flat', cmap='viridis', vmin=vmin, vmax=vmax)
cbar = map.colorbar(cs)
cbar.outline.set_linewidth(1)
map.drawparallels(np.arange(-80.,81.,20.))
map.drawmeridians(np.arange(-180.,181.,20.))

plt.title("September MLD for 1988-2007 in OM4p5nn",fontsize=20)
fig.savefig('./figures/SO_mld09_OM4p5nn.png', bbox_inches='tight', dpi=300)

plt.show()

# %%
fig, axis = plt.subplots(1,1, figsize=(12,12))


fielda = np.ma.masked_greater(mld09_p5,1e6)
fieldb = np.ma.masked_greater(mld09_p5nn,1e6)
field = fielda - fieldb
X = xh_p5[:]
Y = yh_p5[:]

vmin_diff=-200
vmax_diff=200

Lon,Lat = np.meshgrid(X,Y)
x,y = map(Lon,Lat)

cs = map.pcolormesh(x, y, field, shading='flat', cmap='coolwarm', vmin=vmin_diff, vmax=vmax_diff)
cbar = map.colorbar(cs)
cbar.outline.set_linewidth(1)
map.drawparallels(np.arange(-80.,81.,20.))
map.drawmeridians(np.arange(-180.,181.,20.))

plt.title("Difference in Sept MLD for 1988-2007 in OM4p5 - OM4p5nn",fontsize=20)
fig.savefig('./figures/SO_mld09_OM4p5-diff.png', bbox_inches='tight', dpi=300)

plt.show()

# %%
fig, axis = plt.subplots(1,1, figsize=(12,12))

field = np.ma.masked_greater(mld09_p5n,1e6)
X = xh_p5[:]
Y = yh_p5[:]

Lon,Lat = np.meshgrid(X,Y)
x,y = map(Lon,Lat)

cs = map.pcolormesh(x, y, field, shading='flat', cmap='viridis', vmin=vmin, vmax=vmax)
cbar = map.colorbar(cs)
cbar.outline.set_linewidth(1)
map.drawparallels(np.arange(-80.,81.,20.))
map.drawmeridians(np.arange(-180.,181.,20.))

plt.title("September MLD for 1988-2007 in OM4p5n",fontsize=20)
fig.savefig('./figures/SO_mld09_OM4p5n.png', bbox_inches='tight', dpi=300)

plt.show()

# %%
plt.figure(figsize=(20,10))
#plt.subplots(1, 3, figsize=(20,10), gridspec_kw = {'wspace':0, 'hspace':0})

vmin = 0
vmax = 1500

plt.subplot(1,3,1)
field = np.ma.masked_greater(mld09_p25,1e6)
X = xh_p25[:]
Y = yh_p25[:]
Lon,Lat = np.meshgrid(X,Y)
x,y = map(Lon,Lat)
cs = map.pcolormesh(x, y, field, shading='flat', cmap='viridis', vmin=vmin, vmax=vmax)
cbar = map.colorbar(cs)
cbar.outline.set_linewidth(1)
plt.title("OM4p25",fontsize=30)
map.drawparallels(np.arange(-80.,81.,20.))
map.drawmeridians(np.arange(-180.,181.,20.))

plt.subplot(1,3,2)
field = np.ma.masked_greater(mld09_p5,1e6)
X = xh_p5[:]
Y = yh_p5[:]
Lon,Lat = np.meshgrid(X,Y)
x,y = map(Lon,Lat)
cs = map.pcolormesh(x, y, field, shading='flat', cmap='viridis', vmin=vmin, vmax=vmax)
cbar = map.colorbar(cs)
cbar.outline.set_linewidth(1)
plt.title("OM4p5",fontsize=30)
map.drawparallels(np.arange(-80.,81.,20.))
map.drawmeridians(np.arange(-180.,181.,20.))

plt.subplot(1,3,3)
field = np.ma.masked_greater(mld09_p5n,1e6)
X = xh_p5[:]
Y = yh_p5[:]
Lon,Lat = np.meshgrid(X,Y)
x,y = map(Lon,Lat)
cs = map.pcolormesh(x, y, field, shading='flat', cmap='viridis', vmin=vmin, vmax=vmax)
cbar = map.colorbar(cs)
cbar.outline.set_linewidth(1)
plt.title("OM4p5n",fontsize=30)
map.drawparallels(np.arange(-80.,81.,20.))
map.drawmeridians(np.arange(-180.,181.,20.))

plt.tight_layout()
plt.savefig('./figures/SO_mld09_OM4.png', bbox_inches='tight', dpi=300)
plt.show()
